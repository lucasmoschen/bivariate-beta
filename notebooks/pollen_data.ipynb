# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
pollen_data = pd.read_csv('../data/forest_pollen_counts.csv')

# %%
sns.pairplot(data=pollen_data)
plt.show()

# %%
nadarajah_transform = lambda x,y: ((x+y)/100, x/(x+y))

X, Y = nadarajah_transform(pollen_data.Pinus, pollen_data.Abies)
